# %%
A=5
print(A)
# Out:
# 5

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.name "Js-fonseca"
# !git config --global user.email "jufonsecam@unal.edu.co"

# %%
# !git clone https://github.com/Programacion-UNAL202024-2/Piedra-Papel-IA.git
# Out:
# fatal: destination path 'Piedra-Papel-IA' already exists and is not an empty directory.

# %%
# !ls /content
# Out:
# Piedra-Papel-IA  sample_data

# %%
# !mv /content/HOLA.ipynb /content/Piedra-Papel-IA/
# Out:
# mv: cannot stat '/content/ENSAYO.ipynb': No such file or directory

# %%
# !ls /content/Piedra-Papel-IA
# Out:
# ENSAYO.ipynb  P.ipynb  README.md

# %%
# %cd /content/Piedra-Papel-IA
# !git add HOLA.ipynb
# !git commit -m "Subiendo HOLA.ipynb desde Colab"
# !git push origin main
# Out:
# /content/Piedra-Papel-IA
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@268e3cb2a77f.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.name "Js-fonseca"
# !git config --global user.email "jufonsecam@unal.edu.co"

# %%
# !git add HOLA.ipynb
# !git commit -m "Subiendo HOLA.ipynb desde Colab"
# !git push origin main
# Out:
# [main 230ed9a] Subiendo ENSAYO.ipynb desde Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 ENSAYO.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote set-url origin https://Js-fonseca:<NUEVO_TOKEN>@github.com/Programacion-UNAL202024-2/Piedra-Papel-IA.git
